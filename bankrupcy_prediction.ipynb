# %% [markdown]
# <a href="https://colab.research.google.com/github/KavishaMadani/Backrupcy_Prediction/blob/main/bankrupcy_prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
data=pd.read_csv("data.csv")
data
# Out:
#       Bankrupt?   ROA(C) before interest and depreciation before interest  \
# 0             1                                           0.370594
# 1             1                                           0.464291
# 2             1                                           0.426071
# 3             1                                           0.399844
# 4             1                                           0.465022
# ...         ...                                                ...
# 6814          0                                           0.493687
# 6815          0                                           0.475162
# 6816          0                                           0.472725
# 6817          0                                           0.506264
# 6818          0                                           0.493053
#
#        ROA(A) before interest and % after tax  \
# 0                                    0.424389
# 1                                    0.538214
# ...

# %%
null=data.isnull().sum()
null
# Out:
# Bankrupt?                                                   0
#  ROA(C) before interest and depreciation before interest    0
#  ROA(A) before interest and % after tax                     0
#  ROA(B) before interest and depreciation after tax          0
#  Operating Gross Margin                                     0
#                                                            ..
#  Liability to Equity                                        0
#  Degree of Financial Leverage (DFL)                         0
#  Interest Coverage Ratio (Interest expense to EBIT)         0
#  Net Income Flag                                            1
#  Equity to Liability                                        1
# Length: 96, dtype: int64

# %%
data.dropna(inplace=True)
data
# Out:
#       Bankrupt?   ROA(C) before interest and depreciation before interest  \
# 0             1                                           0.370594
# 1             1                                           0.464291
# 2             1                                           0.426071
# 3             1                                           0.399844
# 4             1                                           0.465022
# ...         ...                                                ...
# 2497          0                                           0.656267
# 2498          0                                           0.486033
# 2499          0                                           0.571296
# 2500          0                                           0.611368
# 2501          0                                           0.491103
#
#        ROA(A) before interest and % after tax  \
# 0                                    0.424389
# 1                                    0.538214
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
cor=data.corr()
cor
# Out:
#                                                     Bankrupt?  \
# Bankrupt?                                            1.000000
#  ROA(C) before interest and depreciation before...  -0.260807
#  ROA(A) before interest and % after tax             -0.282941
#  ROA(B) before interest and depreciation after tax  -0.273051
#  Operating Gross Margin                             -0.100043
# ...                                                       ...
#  Liability to Equity                                 0.166812
#  Degree of Financial Leverage (DFL)                  0.010508
#  Interest Coverage Ratio (Interest expense to E...  -0.005509
#  Net Income Flag                                          NaN
#  Equity to Liability                                -0.083048
#
#                                                      ROA(C) before interest and depreciation before interest  \
# Bankrupt?                                                                                   -0.260807
# ...

# %%
sns.heatmap(cor,cmap='coolwarm')
# Out:
# <Axes: >

# %%
X = data.drop(["Bankrupt?"], axis="columns")
y = data["Bankrupt?"]

# %%
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size=0.2)
logreg = LogisticRegression()
logreg.fit(x_train, y_train)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/linear_model/_logistic.py:458: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
logreg.score(x_test, y_test)
# Out:
# 0.968475073313783
